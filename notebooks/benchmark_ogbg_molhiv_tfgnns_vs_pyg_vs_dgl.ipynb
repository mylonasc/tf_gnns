# %% [markdown]
# # OGBG-MOLHIV: tf_gnns vs PyG vs DGL
#
# This notebook runs and inspects the benchmark suite for 100 training steps.

# %%
# !uv run python benchmarks/ogbg_molhiv/run_suite.py --steps 100 --warmup 20 --batch-size 64 --max-graphs 256

# %%
import pandas as pd
df = pd.read_csv('benchmarks/results/ogbg_molhiv_results.csv')
df

# %% [markdown]
# ## Performance commentary template
#
# - Compare `avg_step_ms` across frameworks.
# - Check `std_step_ms` for jitter (often dataloader/allocator effects).
# - For GPU runs, validate synchronization points were respected.
# - If tf_gnns lags, profile sparse matmul vs Python overhead and retracing.
